# %%
#get mean median from csv
import pandas as pd

df = pd.read_csv('yearly_team_stats_combined_filtered.csv')
df.head()
# Out:
#   team  season season_type  total_off_yards  pass_attempts  complete_pass  \
# 0  ARI    2012         REG             4587          587.0          337.0
# 1  ATL    2012        POST              894           74.0           54.0
# 2  ATL    2012         REG             6116          601.0          422.0
# 3  BAL    2012        POST             1679          126.0           73.0
# 4  BAL    2012         REG             5897          549.0          334.0
#
#    incomplete_pass  passing_yards  air_yards  receiving_yards  ...  \
# 0            250.0         3383.0     4862.0           3383.0  ...
# 1             20.0          646.0      920.0            646.0  ...
# 2            179.0         4719.0     5004.0           4719.0  ...
# 3             53.0         1140.0     1541.0           1140.0  ...
# 4            215.0         3996.0     5498.0           3996.0  ...
#
#    rush_snaps_def  pass_snaps_def  average_solo_tackle  average_assist_tackle  \
# ...

# %%
print(df.total_off_yards.mean())
print(df.total_yards.mean())
print(df.rush_snaps_def.mean())
print(df.receiving_yards.mean())
print(df.average_solo_tackle.mean())
print(df.average_sack.mean())
# Out:
# 4404.070446735395
# 7417.017182130584
# 316.28350515463916
# 3012.946735395189
# 39.26252600877573
# 2.419785444171037
